# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd

df=pd.read_csv ('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df.head(5)
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
#clean up the invalid in gender column(this was found after pulling stats)
missing_values = ['Unknown/Invalid']
df2=pd.read_csv ('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv', na_values = missing_values)

# %%
#checking the data type
df3 = df2[['age', 'gender', 'time_in_hospital', 'diabetesMed']]
df3.dtypes
# Out:
# age                 object
# gender              object
# time_in_hospital     int64
# diabetesMed         object
# dtype: object

# %%
#cleaning the age column to remove ( & ])
df3["age"] = df3["age"].str.replace("[", " ")
df3["age"] = df3["age"].str.replace(")", " ")
df3.head(5)
# Out:
# <ipython-input-4-d5a8283d989a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["age"] = df3["age"].str.replace("[", " ")
# <ipython-input-4-d5a8283d989a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["age"] = df3["age"].str.replace(")", " ")
#        age  gender  time_in_hospital diabetesMed
# 0    0-10   Female                 1          No
# 1   10-20   Female                 3         Yes
# 2   20-30   Female                 2         Yes
# 3   30-40     Male                 2         Yes
# 4   40-50     Male                 1         Yes

# %%
#changing age data type from objec to integer
df3['age'].dtype
df3['age'] = df3['age'].astype(str)
df3['age'] = df3['age'].str.extract('(\d+)').astype(int)
df3.dtypes
# Out:
# <ipython-input-5-9211b72b0c1f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['age'] = df3['age'].astype(str)
# <ipython-input-5-9211b72b0c1f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['age'] = df3['age'].str.extract('(\d+)').astype(int)
# age                  int64
# gender              object
# time_in_hospital     int64
# diabetesMed         object
# dtype: object

# %%
#double checking for Na in rows
nan_rows = df3.isna().any(axis=1)
print(nan_rows)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 101761    False
# 101762    False
# 101763    False
# 101764    False
# 101765    False
# Length: 101766, dtype: bool

# %%
#getting the column names
df3.columns
# Out:
# Index(['age', 'gender', 'time_in_hospital', 'diabetesMed'], dtype='object')

# %%
#filtering out only Female from D3
df3[df3['gender']== 'Female']
# Out:
#         age  gender  time_in_hospital diabetesMed
# 0         0  Female                 1          No
# 1        10  Female                 3         Yes
# 2        20  Female                 2         Yes
# 8        80  Female                13         Yes
# 9        90  Female                12         Yes
# ...     ...     ...               ...         ...
# 101757   70  Female                 5         Yes
# 101758   80  Female                 5         Yes
# 101760   60  Female                 6         Yes
# 101762   80  Female                 5         Yes
# 101764   80  Female                10         Yes
#
# [54708 rows x 4 columns]

# %%
#Stats 1: showing the overall mean for Female in all age group
df4=df3.groupby(['age'])['time_in_hospital'].mean().rename('Female Mean')
df4
# Out:
# age
# 0     2.546584
# 10    3.191027
# 20    3.564876
# 30    3.799735
# 40    4.039649
# 50    4.125753
# 60    4.382244
# 70    4.590878
# 80    4.808629
# 90    4.755818
# Name: Female Mean, dtype: float64

# %%
#creating df4 into dataframe
df4 = pd.DataFrame(df4)

# %%
df4.columns
# Out:
# Index(['Female Mean'], dtype='object')

# %%
#Stats 2: showing the mean of time spent in hospital for Female who took med and those who didn't , per age group

grouped_multiple = df3.groupby(['age', 'diabetesMed']).agg({'time_in_hospital': ['mean']})
grouped_multiple.columns = ['Mean']
grouped_multiple = grouped_multiple.reset_index()
print(grouped_multiple)
# Out:
#     age diabetesMed      Mean
# 0     0          No  2.035714
# 1     0         Yes  2.654135
# 2    10          No  3.186813
# 3    10         Yes  3.191667
# 4    20          No  3.307018
# 5    20         Yes  3.631939
# 6    30          No  3.381210
# 7    30         Yes  3.935767
# 8    40          No  3.723246
# 9    40         Yes  4.137070
# 10   50          No  3.768353
# 11   50         Yes  4.228565
# 12   60          No  4.021962
# 13   60         Yes  4.481915
# 14   70          No  4.222222
# 15   70         Yes  4.698182
# 16   80          No  4.470932
# 17   80         Yes  4.920629
# 18   90          No  4.362780
# 19   90         Yes  4.927469

# %%
#double checking the column name to graph
grouped_multiple.columns
# Out:
# Index(['age', 'diabetesMed', 'Mean'], dtype='object')

# %%
#visualization 1: compare medicated vs non medicated mean
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.barplot(data=grouped_multiple, x='age', y='Mean',
                 hue='diabetesMed', ci=None, palette=["green", "red"])

plt.title('Avg time spent in hospital per age group')
plt.xlabel('Age Group')
plt.ylabel('Avg mean time in hospital')
plt.legend(title='Medicated')
plt.show()

#visualization 2 : include overall mean line, medicated mean and non medicated mean line
plt.figure(figsize=(12,8))
sns.lineplot(data=grouped_multiple, x='age', y='Mean',
                 hue='diabetesMed', ci=None, palette=["green", "red"])

ax = sns.lineplot(data=df4, y='Female Mean', x='age', color='blue')  # including the overall Mean line

plt.title('Avg time spent in hospital per age group')
plt.xlabel('Age Group')
plt.ylabel('Avg mean time in hospital')
plt.legend(title='Medicated')

plt.show()
# Out:
# <ipython-input-73-3300b482145f>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=grouped_multiple, x='age', y='Mean',
# <ipython-input-73-3300b482145f>:17: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=grouped_multiple, x='age', y='Mean',

# %% [markdown]
# #observation
#
# Medicated Female shows an increase average more time spent in hospital than Female that did not take any medication. Overall, the average mean spent in hospital for all Females increase over each age group until 90.
